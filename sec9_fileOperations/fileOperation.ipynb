# %%
with open('example.txt', mode='r') as file:
    content = file.read()
    # lines = content.split('\n')
    # for line in lines:
    #     print(line)
    print(content)
# Out:
# Hello World
# Hey This is Good
# Hey this is Something newHey this is Something new

# %%
with open('example.txt', 'w') as file:  ## changes the content 
    file.write("Hello World\n")
    file.write("Hey This is Good\n")

# %%
with open('example.txt', 'a') as file:
    file.write("Hey this is Something new\n")

# %%
with open('example2.txt', mode='w+') as file:
    file.write("Hey This is first line \n")
    file.write("Hey This is second line \n")
    
    file.seek(0)
    
    contents = file.read().strip()
    lines = contents.split('\n')
    print(contents)
    print(lines)
    print(len(lines))
# Out:
# Hey This is first line
# Hey This is second line
# ['Hey This is first line ', 'Hey This is second line']
# 2

# %%
import os 

os.mkdir('package')

items = os.listdir('.')
print(items)
# Out:
# ['example.txt', 'example2.txt', 'fileOperation.ipynb', 'package']

# %%
## Joining paths 

dirName = 'package'
fileName = 'example.txt'

filePath = os.path.join(dirName,fileName)

try:
    os.mkdir(dirName)
except Exception as err:
    pass


with open(filePath, 'w') as file:
    pass

with open(filePath, 'w') as file:
    file.write("Hey This isssss something good\n")

# %%
## Getting the absolute path 

relPath = 'example2.txt'
absPath = os.path.abspath(relPath)

print(absPath)
# Out:
# e:\Development\ML_DL_NLP\sec9_fileOperations\example2.txt
