# %%
try:
    a = 25
    a = r
except:
    print("Phle kro toh shi")
# Out:
# Phle kro toh shi

# %%
try:
    num = int(input("Enter a number: "))
    ans = 5 / num
except Exception as err:
    print(err)
else:
    print(ans.__round__(200))
# Out:
# division by zero

# %%
try:
    num = int(input("Enter a number: "))
    ans = 5 / num
except Exception as err:
    print(err)
else:
    print(ans)
finally:
    print("Execution Complete")
# Out:
# 4.090909098347108e-08
# Execution Complete
