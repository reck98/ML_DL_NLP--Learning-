# %%
print("Hello World")
# Out:
# Hello World

# %%
## Set - > Unordered collection of unique elements
## Set is mutable
## Set is iterable

mySet = {1,1,1,2,2,3,5,4,2,1,3,2,3,2,3,2,3,2,3,13,1,30,2}

print(mySet)
# Out:
# {1, 2, 3, 4, 5, 13, 30}

# %%
mySet.add(1)

print(mySet)

# if mySet.remove(1):
    # print("Found")

print(mySet) 


res = 1 in mySet
print(res)

mySet.discard(9348)
print(mySet)
# Out:
# {1, 2, 3, 4, 5, 13, 30}
# {1, 2, 3, 4, 5, 13, 30}
# True
# {1, 2, 3, 4, 5, 13, 30}

# %%
## Set memnerShip Test 


mySet = {2,5,5,5,5,65,165,165,4,6554,165,12,21,21,21,1,1,2,1,12,22}

print(mySet)
print(65 in mySet)
print(652555 in mySet)
# Out:
# {65, 2, 1, 4, 5, 165, 12, 21, 22, 6554}
# True
# False

# %%
set1 = {1,2,3,4,5,6}
set2 = {4,5,6,7,8,9}

print(set1.union(set2))
print(set1.intersection(set2))
print(set1.difference(set2))
print(set2.difference(set1))
print(set1.symmetric_difference(set2))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {4, 5, 6}
# {1, 2, 3}
# {8, 9, 7}
# {1, 2, 3, 7, 8, 9}

# %%
set1.intersection_update(set2)
print(set1)
# Out:
# {4, 5, 6}

# %%
## Sets methods

set1 = {1,2,3}
set2 = {3,4,5}


print(set1.issubset(set2))  ## subset means all elemenets of set1 are present in set2
print(set1.issuperset(set2))
print(set1.isdisjoint(set2))
# Out:
# False
# False
# False

# %%
text = "hey this is my first time learning first learning python"

words = text.split()   ## Split the text into words gives list 
print(words)

setOfWords = set(words)
print(setOfWords)

print(len(setOfWords))
# Out:
# ['hey', 'this', 'is', 'my', 'first', 'time', 'learning', 'first', 'learning', 'python']
# {'first', 'hey', 'is', 'learning', 'time', 'python', 'this', 'my'}
# 8
