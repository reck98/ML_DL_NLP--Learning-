# %%
age = 25 ## Integer
print(type(age))


height = 5.9 ## Float
print(type(height))
# Out:
# <class 'int'>
# <class 'float'>

# %%
name = "Aashish"
print(name, "and the daya type is" ,type(name))
# Out:
# Aashish and the daya type is <class 'str'>

# %%
isTrue = True
print(isTrue, type(isTrue))
# Out:
# True <class 'bool'>

# %%
isFalse = bool(25)
print(isFalse)
# Out:
# True

# %%
## Common errors

# res = "Hello" + 5 # This will throw an error as we are trying to add string with int

res = "Hello" + " " + str(5)
print(res)
# Out:
# Hello 5

# %%
S = "Aashish Kumar"
print(S.capitalize()) # This will capitalize the first letter of the string

print(S.lower()) # This will convert the string to lowercase

print(S.upper()) # This will convert the string to uppercase
# Out:
# Aashish kumar
# aashish kumar
# AASHISH KUMAR
