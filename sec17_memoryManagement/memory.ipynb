# %%
print('Hello From reck98')
# Out:
# Hello From reck98

# %%
import sys

# %%
a = []

sys.getrefcount(a)
# Out:
# 2

# %%
import gc
gc.enable()

# %%
gc.disable()

# %%
gc.collect()
# Out:
# 5999

# %%
print(gc.get_stats())
# Out:
# [{'collections': 297, 'collected': 8888, 'uncollectable': 0}, {'collections': 26, 'collected': 1040, 'uncollectable': 0}, {'collections': 3, 'collected': 6082, 'uncollectable': 0}]
