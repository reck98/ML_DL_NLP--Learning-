# %%
import math

math.sqrt(25)
# Out:
# 5.0

# %%
from datetime import datetime as dt

now = dt.now()
print(now)
# Out:
# 2025-10-21 14:49:36.640600

# %%
from random import randint as ri

randEle = ri(25,46)

print(randEle)
# Out:
# 31

# %%
from math import sqrt,pow

print(sqrt(16))
print(pow(2,3))
# Out:
# 4.0
# 8.0

# %%
try:
    import ptanhi
except Exception as err:
    print(f"An Error ocurred as {err}")
# Out:
# An Error ocurred as No module named 'ptanhi'

# %%
import os 

os.mkdir('Hey')

print(os.getcwd())

os.rmdir('Hey')
# Out:
# e:\Development\ML_DL_NLP\sec8_Importing Creating Modules And Packages\packagessolution

# %%
import sys
import platform

print(platform.processor())
print(sys.version)
# Out:
# Intel64 Family 6 Model 154 Stepping 3, GenuineIntel
# 3.12.7 (tags/v3.12.7:0b05ead, Oct  1 2024, 03:06:41) [MSC v.1941 64 bit (AMD64)]

# %%
from math import gcd

print(gcd(25,45))
# Out:
# 5

# %%
from datetime import datetime, timedelta

now = datetime.now()
fut = now + timedelta(days=100)

print(now)
print(fut)
# Out:
# 2025-10-21 14:57:44.488290
# 2026-01-29 14:57:44.488290

# %%
import random

l = [random.randint(1,50) for _ in range(5)]
for ele in l:
    print(ele, end=" ")
# Out:
# 1 25 2 19 12
