# %%
print("Hello from reck98")
# Out:
# Hello from reck98

# %%
import logging

logging.basicConfig(
    filename='./app.log',
    filemode= 'w',
    level= logging.DEBUG,
    format= '%(asctime)s | %(name)s | %(levelname)s | %(message)s',
    force=True
)

# %%
try:
    a = 5 / 0
except:
    logging.error("Arithmetic Operator does not do this work")

# %%
logging.warning("Hey this is a warning i got from a app running in the background")
