# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Hello World Hey this is from venv ")
# Out:
# Hello World Hey this is from venv

# %%
import sqlite3 as sql

conn = sql.connect('./example.db')
cursor = conn.cursor()

# %%
cursor.execute('''
    CREATE TABLE IF NOT EXISTS employees(
        id INTEGER PRIMARY KEY,
        name TEXT NOT NULL,
        email TEXT NOT NULL
    )
               ''')

# %%
conn.commit()

# %%
cursor.execute('''
               SELECT * FROM employees
               ''')
