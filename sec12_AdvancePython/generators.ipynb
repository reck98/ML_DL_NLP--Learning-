# %%
def square(n):
    for i in range(n):
        yield i ** 2    ## generate the value and storing it at some local place 

n = 5
for i in square(n):
    print(i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
a = square(6)
a
# Out:
# <generator object square at 0x000001EC81DCE400>

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 next(a)
#
# StopIteration:

# %% [markdown]
# #### Used for large computations or reading large files
#
# ##### As yield does not store anything into memory
